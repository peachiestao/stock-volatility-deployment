# %% [markdown]
# # TSLA Model Monitoring (Evidently)
#
# Reference window: **2020-01-01 → yesterday**
# Current window: **today only**
#
# This notebook fetches features for TSLA and SPY, scales them with your saved `scaler.pkl`, runs predictions using `final_model.keras`, and builds Evidently reports for data & prediction drift.

# %%
# !pip install  evidently yfinance pandas numpy tensorflow joblib ta
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: evidently in c:\users\prabh\appdata\roaming\python\python310\site-packages (0.7.16)
# Requirement already satisfied: yfinance in c:\users\prabh\appdata\roaming\python\python310\site-packages (0.2.66)
# Requirement already satisfied: pandas in c:\users\prabh\appdata\roaming\python\python310\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\prabh\appdata\roaming\python\python310\site-packages (1.23.5)
# Requirement already satisfied: tensorflow in c:\users\prabh\appdata\roaming\python\python310\site-packages (2.12.0)
# Requirement already satisfied: joblib in c:\users\prabh\appdata\roaming\python\python310\site-packages (1.5.2)
# Requirement already satisfied: ta in c:\users\prabh\appdata\roaming\python\python310\site-packages (0.11.0)
# Requirement already satisfied: plotly<6,>=5.10.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (5.24.1)
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (0.14.5)
# Requirement already satisfied: scikit-learn>=1.1.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (1.7.2)
# Requirement already satisfied: nltk>=3.6.7 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (3.9.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (1.15.3)
# Requirement already satisfied: requests>=2.32.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2.32.5)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (6.0.3)
# Requirement already satisfied: pydantic>=1.10.16 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2.12.0)
# Requirement already satisfied: litestar>=2.8.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2.18.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (0.9.0)
# Requirement already satisfied: uvicorn>=0.22.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.38.0)
# Requirement already satisfied: watchdog>=3.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (6.0.0)
# Requirement already satisfied: typer>=0.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (0.20.0)
# Requirement already satisfied: rich>=13 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (14.1.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (0.0.10)
# Requirement already satisfied: dynaconf>=3.2.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (3.2.12)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2025.10.5)
# Requirement already satisfied: urllib3>=1.26.19 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2.5.0)
# Requirement already satisfied: fsspec>=2024.6.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2025.10.0)
# Requirement already satisfied: ujson>=5.4.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (5.11.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2.1.0)
# Requirement already satisfied: uuid6>=2024.7.10 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (2025.0.1)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently) (46.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from plotly<6,>=5.10.0->evidently) (9.1.2)
# Requirement already satisfied: packaging in c:\users\prabh\appdata\roaming\python\python310\site-packages (from plotly<6,>=5.10.0->evidently) (25.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (4.25.8)
# Requirement already satisfied: websockets>=13.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (25.9.23)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.30)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.4.0)
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from requests>=2.32.0->evidently) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from requests>=2.32.0->evidently) (3.10)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from cryptography>=43.0.1->evidently) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\prabh\appdata\roaming\python\python310\site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently) (2.23)
# Requirement already satisfied: appdirs in c:\users\prabh\appdata\roaming\python\python310\site-packages (from iterative-telemetry>=0.0.5->evidently) (1.4.4)
# Requirement already satisfied: filelock in c:\users\prabh\appdata\roaming\python\python310\site-packages (from iterative-telemetry>=0.0.5->evidently) (3.20.0)
# Requirement already satisfied: distro in c:\users\prabh\appdata\roaming\python\python310\site-packages (from iterative-telemetry>=0.0.5->evidently) (1.9.0)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.5.3)
# Requirement already satisfied: anyio>=3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (4.11.0)
# Requirement already satisfied: click in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (8.3.1)
# Requirement already satisfied: exceptiongroup in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (1.3.0)
# Requirement already satisfied: httpx>=0.22 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (0.5.0)
# Requirement already satisfied: msgspec>=0.18.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (0.19.0)
# Requirement already satisfied: multidict>=6.0.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (6.7.0)
# Requirement already satisfied: multipart>=1.2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (1.3.0)
# Requirement already satisfied: polyfactory>=2.6.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (3.0.0)
# Requirement already satisfied: rich-click in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently) (1.9.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from anyio>=3->litestar>=2.8.3->evidently) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\prabh\appdata\roaming\python\python310\site-packages (from httpx>=0.22->litestar>=2.8.3->evidently) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from httpcore==1.*->httpx>=0.22->litestar>=2.8.3->evidently) (0.16.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from nltk>=3.6.7->evidently) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\prabh\appdata\roaming\python\python310\site-packages (from nltk>=3.6.7->evidently) (4.67.1)
# Requirement already satisfied: pyarrow>=7.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas[parquet]>=1.3.5->evidently) (10.0.1)
# Requirement already satisfied: faker>=5.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently) (38.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.16->evidently) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.16->evidently) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.16->evidently) (0.4.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from rich>=13->evidently) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from rich>=13->evidently) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from scikit-learn>=1.1.1->evidently) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from statsmodels>=0.12.2->evidently) (1.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from typer>=0.3->evidently) (1.5.4)
# Requirement already satisfied: colorama in c:\users\prabh\appdata\roaming\python\python310\site-packages (from click->litestar>=2.8.3->evidently) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from typing-inspect>=0.9.0->evidently) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently) (1.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.0.3)

# %%
import sys
python = sys.executable
print("Notebook Python:", python)

! "{python}" -m pip install --upgrade evidently==0.7.16
# Out:
# Notebook Python: c:\Program Files\Python310\python.exe
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: evidently==0.7.16 in c:\users\prabh\appdata\roaming\python\python310\site-packages (0.7.16)
# Requirement already satisfied: plotly<6,>=5.10.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (5.24.1)
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (0.14.5)
# Requirement already satisfied: scikit-learn>=1.1.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (1.7.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.16) (2.1.4)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (1.23.5)
# Requirement already satisfied: nltk>=3.6.7 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (3.9.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (1.15.3)
# Requirement already satisfied: requests>=2.32.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2.32.5)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (6.0.3)
# Requirement already satisfied: pydantic>=1.10.16 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2.12.0)
# Requirement already satisfied: litestar>=2.8.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2.18.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (0.9.0)
# Requirement already satisfied: uvicorn>=0.22.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.16) (0.38.0)
# Requirement already satisfied: watchdog>=3.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (6.0.0)
# Requirement already satisfied: typer>=0.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (0.20.0)
# Requirement already satisfied: rich>=13 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (14.1.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (0.0.10)
# Requirement already satisfied: dynaconf>=3.2.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (3.2.12)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2025.10.5)
# Requirement already satisfied: urllib3>=1.26.19 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2.5.0)
# Requirement already satisfied: fsspec>=2024.6.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2025.10.0)
# Requirement already satisfied: ujson>=5.4.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (5.11.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2.1.0)
# Requirement already satisfied: uuid6>=2024.7.10 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (2025.0.1)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from evidently==0.7.16) (46.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from plotly<6,>=5.10.0->evidently==0.7.16) (9.1.2)
# Requirement already satisfied: packaging in c:\users\prabh\appdata\roaming\python\python310\site-packages (from plotly<6,>=5.10.0->evidently==0.7.16) (25.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from cryptography>=43.0.1->evidently==0.7.16) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.13.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from cryptography>=43.0.1->evidently==0.7.16) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\prabh\appdata\roaming\python\python310\site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently==0.7.16) (2.23)
# Requirement already satisfied: appdirs in c:\users\prabh\appdata\roaming\python\python310\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.16) (1.4.4)
# Requirement already satisfied: filelock in c:\users\prabh\appdata\roaming\python\python310\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.16) (3.20.0)
# Requirement already satisfied: distro in c:\users\prabh\appdata\roaming\python\python310\site-packages (from iterative-telemetry>=0.0.5->evidently==0.7.16) (1.9.0)
# Requirement already satisfied: anyio>=3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (4.11.0)
# Requirement already satisfied: click in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (8.3.1)
# Requirement already satisfied: exceptiongroup in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (1.3.0)
# Requirement already satisfied: httpx>=0.22 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (0.5.0)
# Requirement already satisfied: msgspec>=0.18.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (0.19.0)
# Requirement already satisfied: multidict>=6.0.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (6.7.0)
# Requirement already satisfied: multipart>=1.2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (1.3.0)
# Requirement already satisfied: polyfactory>=2.6.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (3.0.0)
# Requirement already satisfied: rich-click in c:\users\prabh\appdata\roaming\python\python310\site-packages (from litestar>=2.8.3->evidently==0.7.16) (1.9.4)
# Requirement already satisfied: idna>=2.8 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.7.16) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.7.16) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\prabh\appdata\roaming\python\python310\site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.7.16) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from httpcore==1.*->httpx>=0.22->litestar>=2.8.3->evidently==0.7.16) (0.16.0)
# Requirement already satisfied: joblib in c:\users\prabh\appdata\roaming\python\python310\site-packages (from nltk>=3.6.7->evidently==0.7.16) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from nltk>=3.6.7->evidently==0.7.16) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\prabh\appdata\roaming\python\python310\site-packages (from nltk>=3.6.7->evidently==0.7.16) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.16) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.16) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.16) (2025.2)
# Requirement already satisfied: pyarrow>=7.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.16) (10.0.1)
# Requirement already satisfied: faker>=5.0.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.7.16) (38.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.16->evidently==0.7.16) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.16->evidently==0.7.16) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from pydantic>=1.10.16->evidently==0.7.16) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.7.16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from requests>=2.32.0->evidently==0.7.16) (3.4.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from rich>=13->evidently==0.7.16) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from rich>=13->evidently==0.7.16) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.7.16) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from scikit-learn>=1.1.1->evidently==0.7.16) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from statsmodels>=0.12.2->evidently==0.7.16) (1.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from typer>=0.3->evidently==0.7.16) (1.5.4)
# Requirement already satisfied: colorama in c:\users\prabh\appdata\roaming\python\python310\site-packages (from click->litestar>=2.8.3->evidently==0.7.16) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from typing-inspect>=0.9.0->evidently==0.7.16) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.16) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.16) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.16) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\prabh\appdata\roaming\python\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.16) (15.0.1)

# %%
import evidently
print(evidently.__version__)
# Out:
# 0.7.16

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import joblib
import tensorflow as tf
import ta
from datetime import datetime, timedelta

# NEW Evidently imports
from evidently import Report
from evidently.presets import DataDriftPreset, RegressionPreset

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# Load model & scaler
import os
import tensorflow as tf
import joblib

# Path to the best_model folder
MODEL_DIR = os.path.join("best_model")

# Load model & scaler from best_model/
model_path = os.path.join(MODEL_DIR, "final_model.keras")
scaler_path = os.path.join(MODEL_DIR, "scaler.pkl")

print("Loading resources...")

model = tf.keras.models.load_model(model_path)
scaler = joblib.load(scaler_path)

# Determine model input shape
input_shape = model.input_shape
NEEDS_SEQUENCE = len(input_shape) == 3
SEQ_LENGTH = input_shape[1] if NEEDS_SEQUENCE else 1

print(f"Model loaded. Sequence model: {NEEDS_SEQUENCE}, SEQ_LENGTH: {SEQ_LENGTH}")
# Out:
# Loading resources...
# Model loaded. Sequence model: False, SEQ_LENGTH: 1

# %%
def engineer(df):
    # Ensure normal columns when yfinance returns MultiIndex
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = [col[0] for col in df.columns]
    df = df.copy()
    df['Volatility'] = (df['High'] - df['Low']) / df['Close']
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()
    df['SMA'] = ta.trend.SMAIndicator(df['Close'], window=21).sma_indicator()
    df['Return'] = (df['Close'] - df['Open']) / df['Open']
    return df[["Volatility", "RSI", "SMA", "Return", "Volume"]]

print('feature engineering function ready')
# Out:
# feature engineering function ready

# %%
def fetch_dataset_by_date(ticker, start_date, end_date):
    # Download target and SPY for the same period
    df_target = yf.download(ticker, start=start_date, end=end_date, progress=False)
    df_spy = yf.download('SPY', start=start_date, end=end_date, progress=False)

    if df_target.empty or df_spy.empty:
        raise ValueError(f'No data for given range: {start_date} to {end_date}')

    f_target = engineer(df_target)
    f_spy = engineer(df_spy)

    merged = pd.merge(f_target, f_spy, left_index=True, right_index=True, suffixes=("_TSLA","_SPY"))
    merged = merged.dropna()

    # Scale features
    scaled = scaler.transform(merged.values)

    # Build model inputs based on whether model uses sequences
    if NEEDS_SEQUENCE:
        if len(scaled) <= SEQ_LENGTH:
            raise ValueError('Not enough rows to form one sequence')
        X = np.array([scaled[i-SEQ_LENGTH:i] for i in range(SEQ_LENGTH, len(scaled))])
        y = merged.iloc[SEQ_LENGTH:].copy()
    else:
        X = scaled
        y = merged.copy()

    preds = model.predict(X).flatten()
    y['prediction'] = preds
    return y

print('fetch function ready')
# Out:
# fetch function ready

# %%
def fetch_dataset_by_date(ticker, start_date, end_date):

    # Convert dates
    start_dt = pd.to_datetime(start_date)
    preload_start = (start_dt - timedelta(days=60)).strftime("%Y-%m-%d")

    # Fetch extended history for SMA/RSI warmup
    df_target = yf.download(ticker, start=preload_start, end=end_date, progress=False)
    df_spy    = yf.download('SPY',    start=preload_start, end=end_date, progress=False)

    if df_target.empty or df_spy.empty:
        raise ValueError(f'No data for given range: {start_date} to {end_date}')

    f_target = engineer(df_target)
    f_spy = engineer(df_spy)

    # Align only AFTER engineering
    merged = pd.merge(f_target, f_spy, left_index=True, right_index=True, suffixes=("_TSLA","_SPY"))

    # Keep only rows within the actual range requested
    merged = merged.loc[start_date:end_date]

    # Drop NaN rows AFTER trimming to date range
    merged = merged.dropna()

    # If nothing survives, it's normal — user requested too short period
    if len(merged) == 0:
        raise ValueError("Merged dataset empty — need more days for indicators (SMA, RSI).")

    # Scale features
    scaled = scaler.transform(merged.values)

    # Build model inputs
    if NEEDS_SEQUENCE:
        if len(scaled) <= SEQ_LENGTH:
            raise ValueError('Not enough rows to form one sequence')
        X = np.array([scaled[i-SEQ_LENGTH:i] for i in range(SEQ_LENGTH, len(scaled))])
        y = merged.iloc[SEQ_LENGTH:].copy()
    else:
        X = scaled
        y = merged.copy()

       # Model predictions
    
    preds = model.predict(X).flatten()
    y['prediction'] = preds
    
    # ---------------------------------------------
    #  ADD TARGET COLUMN (rule)
    # ---------------------------------------------
    y['target'] = (y['prediction'] >= 0.5).astype(int)

    return y

# %%
from datetime import datetime, timedelta

# Reference range: from 2020-01-01 to yesterday
REFERENCE_START = "2025-01-01"
REFERENCE_END = (datetime.now() - timedelta(days=1)).strftime("%Y-%m-%d")

print('Building reference dataset from', REFERENCE_START, 'to', REFERENCE_END)

reference = fetch_dataset_by_date('TSLA', REFERENCE_START, REFERENCE_END)
reference.to_csv('reference_dataset_tsla.csv')
reference.tail()
# Out:
# Building reference dataset from 2025-01-01 to 2025-11-21
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2388339347.py:8: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2388339347.py:9: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
# 7/7 [==============================] - 0s 2ms/step
# C:\Users\prabh\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names
#             Volatility_TSLA   RSI_TSLA    SMA_TSLA  Return_TSLA  Volume_TSLA  \
# Date
# 2025-11-14         0.072734  41.068227  442.574764     0.046725    105506700
# 2025-11-17         0.061675  42.637983  441.127622     0.025530    102214300
# 2025-11-18         0.037857  40.679490  438.928574    -0.010188     80688600
# 2025-11-19         0.032872  41.709545  437.090002    -0.005392     72047700
# 2025-11-20         0.086532  39.356599  435.007145    -0.046789    113548800
#
#             Volatility_SPY    RSI_SPY     SMA_SPY  Return_SPY  Volume_SPY  \
# Date
# 2025-11-14        0.018439  48.271921  676.885713    0.009844    96846700
# 2025-11-17        0.017336  43.209748  676.946664   -0.006018    90456100
# 2025-11-18        0.014029  39.251380  676.412380   -0.003051   114467500
# 2025-11-19        0.012964  41.867554  676.000000    0.002800    94703000
# 2025-11-20        0.036274  35.370223  675.272859   -0.030286   165293500
#
#             prediction  target
# Date
# 2025-11-14    0.796764       1
# 2025-11-17    0.800741       1
# 2025-11-18    0.734298       1
# 2025-11-19    0.682935       1
# 2025-11-20    0.931952       1

# %%
def get_last_n_trading_days(ticker="TSLA", n=7):
    """Returns a list of the last n trading day dates for the given ticker."""
    today = datetime.now().date()
    found_days = []

    # Search backwards up to 30 days (covers long holidays)
    for i in range(30):
        day = today - timedelta(days=i)
        next_day = day + timedelta(days=1)

        df = yf.download(
            ticker,
            start=day.strftime("%Y-%m-%d"),
            end=next_day.strftime("%Y-%m-%d"),
            progress=False
        )

        if not df.empty:
            found_days.append(day)

        # Stop when we have enough valid days
        if len(found_days) == n:
            break

    if len(found_days) < n:
        raise ValueError("Not enough trading days found in last 30 days.")
    
    print('Returned days',found_days )
    # Return sorted oldest → newest
    return sorted(found_days)

# %%
from datetime import datetime, timedelta

# Get last n trading days for TSLA
trading_days = get_last_n_trading_days("TSLA", n=22)

CURRENT_START = trading_days[0].strftime("%Y-%m-%d")  # oldest of the n
CURRENT_END   = trading_days[-1].strftime("%Y-%m-%d") # most recent trading day

print('Building reference dataset from', CURRENT_START, 'to', CURRENT_END)

current = fetch_dataset_by_date('TSLA', CURRENT_START, CURRENT_END)
current.to_csv('current_dataset_tsla.csv')
current.tail()
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-11-16 -> 2025-11-17)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-11-15 -> 2025-11-16)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-11-09 -> 2025-11-10)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-11-08 -> 2025-11-09)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-11-02 -> 2025-11-03)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-11-01 -> 2025-11-02)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-10-26 -> 2025-10-27)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
#
# 1 Failed download:
# ['TSLA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-10-25 -> 2025-10-26)')
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2742460379.py:11: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2388339347.py:8: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Local\Temp\ipykernel_88696\2388339347.py:9: FutureWarning:
#
# YF.download() has changed argument auto_adjust default to True
#
# C:\Users\prabh\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names
# Returned days [datetime.date(2025, 11, 22), datetime.date(2025, 11, 21), datetime.date(2025, 11, 20), datetime.date(2025, 11, 19), datetime.date(2025, 11, 18), datetime.date(2025, 11, 17), datetime.date(2025, 11, 14), datetime.date(2025, 11, 13), datetime.date(2025, 11, 12), datetime.date(2025, 11, 11), datetime.date(2025, 11, 10), datetime.date(2025, 11, 7), datetime.date(2025, 11, 6), datetime.date(2025, 11, 5), datetime.date(2025, 11, 4), datetime.date(2025, 11, 3), datetime.date(2025, 10, 31), datetime.date(2025, 10, 30), datetime.date(2025, 10, 29), datetime.date(2025, 10, 28), datetime.date(2025, 10, 27), datetime.date(2025, 10, 24)]
# Building reference dataset from 2025-10-24 to 2025-11-22
# 1/1 [==============================] - 0s 36ms/step
#             Volatility_TSLA   RSI_TSLA    SMA_TSLA  Return_TSLA  Volume_TSLA  \
# Date
# 2025-11-17         0.061675  42.507084  441.127622     0.025530    102214300
# 2025-11-18         0.037857  40.541245  438.928574    -0.010188     80688600
# 2025-11-19         0.032872  41.580641  437.090002    -0.005392     72047700
# 2025-11-20         0.086532  39.220094  435.007145    -0.046789    113548800
# 2025-11-21         0.048684  38.118699  432.250478    -0.027913    100180500
#
#             Volatility_SPY    RSI_SPY     SMA_SPY  Return_SPY  Volume_SPY  \
# Date
# 2025-11-17        0.017336  43.055384  676.946664   -0.006018    90456100
# 2025-11-18        0.014029  39.076828  676.412380   -0.003051   114467500
# 2025-11-19        0.012964  41.722363  676.000000    0.002800    94703000
# 2025-11-20        0.036274  35.202082  675.272859   -0.030286   165293500
# 2025-11-21        0.020788  41.534569  674.666670    0.006076   123872700
#
#             prediction  target
# Date
# 2025-11-17    0.801463       1
# 2025-11-18    0.735258       1
# 2025-11-19    0.683865       1
# 2025-11-20    0.932222       1
# 2025-11-21    0.796136       1

# %%
import subprocess
def trigger_retraining():
    """
    Mechanism to trigger action. 
    In a real system, this might call an Airflow DAG or AWS Lambda.
    """
    print("\n[ACTION TRIGGERED]  MODEL RETRAINING REQUESTED")
    print("Reason: Significant Data Drift detected.")
    try:
        print("[INFO] Launching local retraining job using train_model.py...")
        subprocess.run(["python", "train_model.py"], check=True)
        print("[SUCCESS] Retraining completed. New model ready.")
    except Exception as e:
        print("[ERROR] Retraining failed:", str(e))

# %%
import smtplib
from email.mime.text import MIMEText
import yaml

def load_config(path="config.yaml"):
    """
    Load YAML configuration file.
    """
    try:
        with open(path, "r") as f:
            return yaml.safe_load(f)
    except Exception as e:
        print(f"[CONFIG ERROR] Failed to load {path}: {e}")
        return None


def send_email_alert(subject, body, config_path="config.yaml"):
    """
    Sends an email using SMTP settings loaded from config.yaml.
    """

    config = load_config(config_path)
    if config is None:
        return False

    # Read settings from YAML
    try:
        smtp_server = config["smtp"]["server"]
        smtp_port   = config["smtp"]["port"]
        smtp_user   = config["smtp"]["user"]
        smtp_pass   = config["smtp"]["pass"]

        email_from  = config["email"]["from"]
        email_to    = config["email"]["to"]

    except KeyError as e:
        print(f"[EMAIL ERROR] Missing required YAML key: {e}")
        return False

    # Create the email message
    msg = MIMEText(body)
    msg["Subject"] = subject
    msg["From"]    = email_from
    msg["To"]      = email_to

    # Send using SMTP server
    try:
        server = smtplib.SMTP(smtp_server, smtp_port)
        server.starttls()
        server.login(smtp_user, smtp_pass)
        server.sendmail(email_from, [email_to], msg.as_string())
        server.quit()

        print("[EMAIL SENT] Alert email successfully delivered.")
        return True

    except Exception as e:
        print(f"[EMAIL ERROR] Failed to send email: {e}")
        return False

# %%
def send_alert(drift_score, drifted_features):
    """
    Sends email alert when drift is detected.
    """

    subject = f"[ML Drift Alert] Drift Score {drift_score:.2f}"
    body = (
        " MACHINE LEARNING DRIFT DETECTED \n\n"
        f"Drift Score: {drift_score:.4f}\n"
        f"Drifting Features:\n - " + "\n - ".join(drifted_features) + "\n\n"
        "Action Required: Model retraining triggered.\n"
    )

    print("\n[ALERT] Data Drift Detected!")
    print(f"Sending Email...")

    send_email_alert(subject, body)

# %%
# Training Dataset Summary
from evidently import Report
from evidently.metrics import *
from evidently.presets import *

reference = pd.read_csv("reference_dataset_tsla.csv")
current = pd.read_csv("current_dataset_tsla.csv")

report = Report([
    DataSummaryPreset()
])

my_eval = report.run(reference, None)
#my_eval
print("Saved reports/referncedatasetsummary_report.html")
my_eval.save_html("reports/referncedatasetsummary_report.html")
# Out:
# Saved reports/referncedatasetsummary_report.html

# %%
# Current  Dataset Summary
from evidently import Report
from evidently.metrics import *
from evidently.presets import *

reference = pd.read_csv("reference_dataset_tsla.csv")
current = pd.read_csv("current_dataset_tsla.csv")

report = Report([
    DataSummaryPreset()
])

my_eval = report.run(reference_data=reference,
        current_data=current)
#my_eval
print("Saved reports/refernce_current_datasetsummary_report.html")
my_eval.save_html("reports/refernce_current_datasetsummary_report.html")
# Out:
# Saved reports/refernce_current_datasetsummary_report.html

# %%
# Build Evidently report only if we have current data
import os

os.makedirs("reports", exist_ok=True)

from evidently import Report
from evidently.presets import DataDriftPreset, RegressionPreset
import pandas as pd

reference = pd.read_csv("reference_dataset_tsla.csv")
current = pd.read_csv("current_dataset_tsla.csv")


if current.empty:
    print("No current data available.")
else:
    print("Running Evidently report...")

    # Data Drift Evaluation

    feature_cols = [
    'Volatility_TSLA','RSI_TSLA','SMA_TSLA','Return_TSLA','Volume_TSLA',
    'Volatility_SPY','RSI_SPY','SMA_SPY','Return_SPY','Volume_SPY'
    ]

    prediction_cols =['prediction','target']

    reference_features = reference[feature_cols]
    current_features = current[feature_cols]
    
    report = Report(metrics=[
        DataDriftPreset()
    ])

    data_eval=report.run(
        reference_data=reference_features,
        current_data=current_features
    )

    report

    data_eval.save_html("reports/tsla_datadrift_report.html")

    print("Saved reports/tsla_datadrift_report.html")

    # Prediction Drift Evaluation

    reference_prediction_features = reference[prediction_cols]
    current_prediction_features = current[prediction_cols]
    
    
    pred_eval=report.run(
        reference_data=reference_prediction_features,
        current_data=current_prediction_features
    )

    pred_eval.save_html("reports/tsla_targetdrift_report.html")

    print("Saved reports/tsla_targetdrift_report.html")

    #  Check for Anomalies programmatically
    # Extract metric result as a Python dict
    data_eval.save_json("reports/tsla_datadrift_report.json")
    results = eval.dict()
    
    # Navigate JSON structure to find drift share
    DRIFT_THRESHOLD = 0.3   # you choose

    # --- Extract global drift share from DriftedColumnsCount ---
    drift_count_metric = results["metrics"][0]   # ALWAYS DriftedColumnsCount

    drift_share = drift_count_metric["value"]["share"]
    num_drifted = drift_count_metric["value"]["count"]

    print(f"Drift Share: {drift_share}, Drifted Features: {num_drifted}")

    # --- Extract per-feature drift based on ValueDrift metrics ---
    drifted_columns = []

    for metric in results["metrics"]:
        if metric["config"]["type"] == "evidently:metric_v2:ValueDrift":
            col = metric["config"]["column"]
            score = metric["value"]
            threshold = metric["config"]["threshold"]

            if score > threshold:
                drifted_columns.append(col)

    # --- Decision Logic ---
    if drift_share > DRIFT_THRESHOLD:
        print("[ALERT] Significant drift detected!")
        print("Drifted columns:", drifted_columns)
        send_alert(drift_share, drifted_columns)
        trigger_retraining()
    else:
        print("[STATUS] Healthy — no significant drift detected.")
# Out:
# Running Evidently report...
# Saved reports/tsla_datadrift_report.html
# Saved reports/tsla_targetdrift_report.html
# Drift Share: 1.0, Drifted Features: 12.0
# [ALERT] Significant drift detected!
# Drifted columns: ['Volatility_TSLA', 'RSI_TSLA', 'SMA_TSLA', 'Return_TSLA', 'Volume_TSLA', 'Volatility_SPY', 'RSI_SPY', 'SMA_SPY', 'Return_SPY', 'Volume_SPY', 'prediction', 'Date']
#
# [ALERT]  Data Drift Detected!
# Send an Email Drift Score: 1.00
# Drifting Features: ['Volatility_TSLA', 'RSI_TSLA', 'SMA_TSLA', 'Return_TSLA', 'Volume_TSLA', 'Volatility_SPY', 'RSI_SPY', 'SMA_SPY', 'Return_SPY', 'Volume_SPY', 'prediction', 'Date']
#
# [ACTION TRIGGERED]  MODEL RETRAINING REQUESTED
# Reason: Significant Data Drift detected.

# %% [markdown]
# ## Notes
# - If markets are closed (weekends/holidays) today's download may be empty. The notebook will detect and skip the Evidently run.
# - The notebook expects `final_model.keras` and `scaler.pkl` to be present in the same working directory.
# - Generated files:
#   - `reference_dataset_tsla.csv`
#   - `current_dataset_tsla.csv` (may be empty on closed-market days)
#   - `tsla_monitoring_report.html`
#   - `tsla_monitoring_dashboard.html`
